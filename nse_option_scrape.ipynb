# %%
import requests
import lxml.html as lh
import pandas as pd
import numpy as np
import datetime
import re

def takenum(s):
    '''Takes numeric only and removes everything else'''
    try:
        return float(re.findall("[-+]?\d*\.\d+|\d+", s)[0])
    except IndexError:
        np.nan

# %%
url = 'https://www.nseindia.com/marketinfo/companyTracker/mtOptionKeys.jsp?companySymbol=ACC&indexSymbol=NIFTY&series=EQ&instrument=OPTSTK&date=-'

# Create a handle, page, to handle the contents of the website
page = requests.get(url)

#Store the contents of the website under doc
doc = lh.fromstring(page.content)

# Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
# Option table is contained in rows of length 21
opt_table = [t for t in tr_elements if len(t) == 21]
tbl_header = [i.text_content() for i in opt_table[0]]

# %%
# Extract symbol and expiry
txt = ''.join([t.text_content() for t in doc.xpath("//td[contains(@class, 'specialhead21')]")[4]])

strip_chars = [ord('\n'), ord('\xa0'), ord('\t')]
char_table = {s: ' ' for s in strip_chars}

sym_exp = txt.translate(char_table).split()
symbol = sym_exp[0]
expiry = datetime.datetime.strftime(datetime.datetime.strptime(sym_exp[3], '%d%b%Y'), '%Y%m%d')

# %%
tbl_header = [l.text_content().strip() for l in opt_table[0]]

# %%
tbl_new_head = []
for i in range(1, len(opt_table)):
    for k, j in enumerate(opt_table[i]):
        if k < 10:
            tbl_new_head.append(('call_'+tbl_header[k], j.text_content().strip()))
        elif k == 10:
            tbl_new_head.append((tbl_header[k], j.text_content().strip()))
        else:
            tbl_new_head.append(('put_'+tbl_header[k], takenum(j.text_content())))

# %%
tbl_new_head
# Out:
# [('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '413.40'),
#  ('call_OfferPrice', '435.45'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1120.00'),
#  ('put_BidQty', None),
#  ('put_BidPrice', None),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '393.65'),
#  ('call_OfferPrice', '415.65'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1140.00'),
#  ('put_BidQty', None),
#  ('put_BidPrice', None),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '377.10'),
#  ('call_OfferPrice', '395.95'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1160.00'),
#  ('put_BidQty', 400.0),
#  ('put_BidPrice', 0.15),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '355.35'),
#  ('call_OfferPrice', '377.95'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1180.00'),
#  ('put_BidQty', 400.0),
#  ('put_BidPrice', 0.15),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '335.85'),
#  ('call_OfferPrice', '356.80'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1200.00'),
#  ('put_BidQty', 800.0),
#  ('put_BidPrice', 0.15),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '317.00'),
#  ('call_OfferPrice', '339.90'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1220.00'),
#  ('put_BidQty', 400.0),
#  ('put_BidPrice', 0.15),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '299.50'),
#  ('call_OfferPrice', '318.50'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1240.00'),
#  ('put_BidQty', 2.0),
#  ('put_BidPrice', 0.1),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '-'),
#  ('call_BidPrice', '-'),
#  ('call_OfferPrice', '-'),
#  ('call_OfferQty', '-'),
#  ('Strike Price', '1260.00'),
#  ('put_BidQty', 2.0),
#  ('put_BidPrice', 0.2),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '261.60'),
#  ('call_OfferPrice', '282.20'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1280.00'),
#  ('put_BidQty', 3.0),
#  ('put_BidPrice', 0.2),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '242.75'),
#  ('call_OfferPrice', '263.25'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1300.00'),
#  ('put_BidQty', 2.0),
#  ('put_BidPrice', 0.3),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '222.45'),
#  ('call_OfferPrice', '244.40'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1320.00'),
#  ('put_BidQty', 2.0),
#  ('put_BidPrice', 0.3),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '204.45'),
#  ('call_OfferPrice', '223.80'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1340.00'),
#  ('put_BidQty', 1.0),
#  ('put_BidPrice', 2.55),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '400'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '187.55'),
#  ('call_OfferPrice', '204.80'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1360.00'),
#  ('put_BidQty', 2.0),
#  ('put_BidPrice', 2.15),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '1,200'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '164.80'),
#  ('call_OfferPrice', '186.90'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1380.00'),
#  ('put_BidQty', 3.0),
#  ('put_BidPrice', 7.15),
#  ('put_OfferPrice', 17.95),
#  ('put_OfferQty', 4.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', 400.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '800'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '800'),
#  ('call_BidPrice', '151.15'),
#  ('call_OfferPrice', '168.75'),
#  ('call_OfferQty', '2,800'),
#  ('Strike Price', '1400.00'),
#  ('put_BidQty', 800.0),
#  ('put_BidPrice', 12.4),
#  ('put_OfferPrice', 17.0),
#  ('put_OfferQty', 4.0),
#  ('put_Volume', 4.0),
#  ('put_NetChange', 6.15),
#  ('put_LTP', 15.95),
#  ('put_OpenInterest', 6.0),
#  ('put_Change in Open Interest', 800.0),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '2,800'),
#  ('call_BidPrice', '134.20'),
#  ('call_OfferPrice', '155.05'),
#  ('call_OfferQty', '2,800'),
#  ('Strike Price', '1420.00'),
#  ('put_BidQty', 800.0),
#  ('put_BidPrice', 15.45),
#  ('put_OfferPrice', 22.0),
#  ('put_OfferQty', 6.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', 2.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '800'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '2,400'),
#  ('call_BidPrice', '117.75'),
#  ('call_OfferPrice', '136.70'),
#  ('call_OfferQty', '4,400'),
#  ('Strike Price', '1440.00'),
#  ('put_BidQty', 1.0),
#  ('put_BidPrice', 18.2),
#  ('put_OfferPrice', 28.95),
#  ('put_OfferQty', 6.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', 2.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '1,200'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '4,000'),
#  ('call_BidPrice', '102.80'),
#  ('call_OfferPrice', '121.95'),
#  ('call_OfferQty', '5,200'),
#  ('Strike Price', '1460.00'),
#  ('put_BidQty', 2.0),
#  ('put_BidPrice', 22.55),
#  ('put_OfferPrice', 25.15),
#  ('put_OfferQty', 400.0),
#  ('put_Volume', 3.0),
#  ('put_NetChange', -0.15),
#  ('put_LTP', 23.85),
#  ('put_OpenInterest', 5.0),
#  ('put_Change in Open Interest', 800.0),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '800'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '5,600'),
#  ('call_BidPrice', '89.80'),
#  ('call_OfferPrice', '105.50'),
#  ('call_OfferQty', '4,800'),
#  ('Strike Price', '1480.00'),
#  ('put_BidQty', 400.0),
#  ('put_BidPrice', 29.8),
#  ('put_OfferPrice', 57.95),
#  ('put_OfferQty', 800.0),
#  ('put_Volume', 2.0),
#  ('put_NetChange', -1.25),
#  ('put_LTP', 18.75),
#  ('put_OpenInterest', 1.0),
#  ('put_Change in Open Interest', 800.0),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '1,200'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '1,600'),
#  ('call_BidPrice', '81.25'),
#  ('call_OfferPrice', '89.50'),
#  ('call_OfferQty', '4,400'),
#  ('Strike Price', '1500.00'),
#  ('put_BidQty', 400.0),
#  ('put_BidPrice', 36.45),
#  ('put_OfferPrice', 37.6),
#  ('put_OfferQty', 400.0),
#  ('put_Volume', 107.0),
#  ('put_NetChange', 3.35),
#  ('put_LTP', 36.85),
#  ('put_OpenInterest', 20.0),
#  ('put_Change in Open Interest', 4.0),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '1,600'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '5,600'),
#  ('call_BidPrice', '67.60'),
#  ('call_OfferPrice', '80.25'),
#  ('call_OfferQty', '6,000'),
#  ('Strike Price', '1520.00'),
#  ('put_BidQty', 800.0),
#  ('put_BidPrice', 43.25),
#  ('put_OfferPrice', 46.15),
#  ('put_OfferQty', 800.0),
#  ('put_Volume', 35.0),
#  ('put_NetChange', 3.95),
#  ('put_LTP', 45.5),
#  ('put_OpenInterest', 10.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '1,200'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '64.20'),
#  ('call_NetChange', '12.45'),
#  ('call_Volume', '1'),
#  ('call_BidQty', '400'),
#  ('call_BidPrice', '60.30'),
#  ('call_OfferPrice', '69.90'),
#  ('call_OfferQty', '6,400'),
#  ('Strike Price', '1540.00'),
#  ('put_BidQty', 400.0),
#  ('put_BidPrice', 53.15),
#  ('put_OfferPrice', 55.25),
#  ('put_OfferQty', 400.0),
#  ('put_Volume', 36.0),
#  ('put_NetChange', 9.45),
#  ('put_LTP', 56.95),
#  ('put_OpenInterest', 12.0),
#  ('put_Change in Open Interest', 6.0),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '5,200'),
#  ('call_Change in Open Interest', '2,000'),
#  ('call_LTP', '51.25'),
#  ('call_NetChange', '1.80'),
#  ('call_Volume', '23'),
#  ('call_BidQty', '400'),
#  ('call_BidPrice', '50.60'),
#  ('call_OfferPrice', '52.25'),
#  ('call_OfferQty', '400'),
#  ('Strike Price', '1560.00'),
#  ('put_BidQty', 400.0),
#  ('put_BidPrice', 62.55),
#  ('put_OfferPrice', 67.0),
#  ('put_OfferQty', 1.0),
#  ('put_Volume', 9.0),
#  ('put_NetChange', 16.6),
#  ('put_LTP', 75.0),
#  ('put_OpenInterest', 14.0),
#  ('put_Change in Open Interest', 2.0),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '14,400'),
#  ('call_Change in Open Interest', '5,200'),
#  ('call_LTP', '43.10'),
#  ('call_NetChange', '1.05'),
#  ('call_Volume', '58'),
#  ('call_BidQty', '400'),
#  ('call_BidPrice', '42.25'),
#  ('call_OfferPrice', '43.50'),
#  ('call_OfferQty', '400'),
#  ('Strike Price', '1580.00'),
#  ('put_BidQty', 4.0),
#  ('put_BidPrice', 71.0),
#  ('put_OfferPrice', 78.0),
#  ('put_OfferQty', 400.0),
#  ('put_Volume', 1.0),
#  ('put_NetChange', -14.35),
#  ('put_LTP', 59.95),
#  ('put_OpenInterest', 2.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '48,800'),
#  ('call_Change in Open Interest', '6,000'),
#  ('call_LTP', '36.80'),
#  ('call_NetChange', '3.30'),
#  ('call_Volume', '212'),
#  ('call_BidQty', '400'),
#  ('call_BidPrice', '34.70'),
#  ('call_OfferPrice', '35.80'),
#  ('call_OfferQty', '400'),
#  ('Strike Price', '1600.00'),
#  ('put_BidQty', 1.0),
#  ('put_BidPrice', 83.85),
#  ('put_OfferPrice', 90.6),
#  ('put_OfferQty', 2.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', 5.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '45,200'),
#  ('call_Change in Open Interest', '15,200'),
#  ('call_LTP', '28.50'),
#  ('call_NetChange', '0.30'),
#  ('call_Volume', '177'),
#  ('call_BidQty', '400'),
#  ('call_BidPrice', '27.70'),
#  ('call_OfferPrice', '28.80'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1620.00'),
#  ('put_BidQty', 5.0),
#  ('put_BidPrice', 95.25),
#  ('put_OfferPrice', 104.45),
#  ('put_OfferQty', 3.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', 2.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '14,000'),
#  ('call_Change in Open Interest', '2,000'),
#  ('call_LTP', '22.00'),
#  ('call_NetChange', '1.50'),
#  ('call_Volume', '34'),
#  ('call_BidQty', '2,000'),
#  ('call_BidPrice', '21.05'),
#  ('call_OfferPrice', '23.95'),
#  ('call_OfferQty', '400'),
#  ('Strike Price', '1640.00'),
#  ('put_BidQty', 6.0),
#  ('put_BidPrice', 107.05),
#  ('put_OfferPrice', 118.7),
#  ('put_OfferQty', 4.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', 2.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '11,200'),
#  ('call_Change in Open Interest', '4,000'),
#  ('call_LTP', '20.00'),
#  ('call_NetChange', '4.25'),
#  ('call_Volume', '15'),
#  ('call_BidQty', '6,000'),
#  ('call_BidPrice', '15.25'),
#  ('call_OfferPrice', '19.85'),
#  ('call_OfferQty', '400'),
#  ('Strike Price', '1660.00'),
#  ('put_BidQty', 4.0),
#  ('put_BidPrice', 124.15),
#  ('put_OfferPrice', None),
#  ('put_OfferQty', None),
#  ('put_Volume', 2.0),
#  ('put_NetChange', 2.0),
#  ('put_LTP', 117.0),
#  ('put_OpenInterest', 1.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '95,200'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '15.10'),
#  ('call_NetChange', '3.35'),
#  ('call_Volume', '68'),
#  ('call_BidQty', '2,400'),
#  ('call_BidPrice', '12.35'),
#  ('call_OfferPrice', '16.40'),
#  ('call_OfferQty', '1,200'),
#  ('Strike Price', '1680.00'),
#  ('put_BidQty', 6.0),
#  ('put_BidPrice', 137.25),
#  ('put_OfferPrice', 156.85),
#  ('put_OfferQty', 6.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '19,200'),
#  ('call_Change in Open Interest', '1,200'),
#  ('call_LTP', '8.90'),
#  ('call_NetChange', '-1.55'),
#  ('call_Volume', '11'),
#  ('call_BidQty', '5,200'),
#  ('call_BidPrice', '9.05'),
#  ('call_OfferPrice', '12.70'),
#  ('call_OfferQty', '400'),
#  ('Strike Price', '1700.00'),
#  ('put_BidQty', 4.0),
#  ('put_BidPrice', 156.15),
#  ('put_OfferPrice', 173.1),
#  ('put_OfferQty', 2.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', 400.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '2,800'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '6,000'),
#  ('call_BidPrice', '6.55'),
#  ('call_OfferPrice', '16.95'),
#  ('call_OfferQty', '8,800'),
#  ('Strike Price', '1720.00'),
#  ('put_BidQty', 1.0),
#  ('put_BidPrice', 171.3),
#  ('put_OfferPrice', 188.5),
#  ('put_OfferQty', 1.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', 2.0),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '1,600'),
#  ('call_Change in Open Interest', '1,200'),
#  ('call_LTP', '6.40'),
#  ('call_NetChange', '-3.10'),
#  ('call_Volume', '6'),
#  ('call_BidQty', '400'),
#  ('call_BidPrice', '5.55'),
#  ('call_OfferPrice', '8.10'),
#  ('call_OfferQty', '800'),
#  ('Strike Price', '1740.00'),
#  ('put_BidQty', 3.0),
#  ('put_BidPrice', 191.0),
#  ('put_OfferPrice', 206.4),
#  ('put_OfferQty', 3.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '6.00'),
#  ('call_NetChange', '-112.65'),
#  ('call_Volume', '1'),
#  ('call_BidQty', '8,000'),
#  ('call_BidPrice', '2.00'),
#  ('call_OfferPrice', '6.95'),
#  ('call_OfferQty', '1,200'),
#  ('Strike Price', '1760.00'),
#  ('put_BidQty', 2.0),
#  ('put_BidPrice', 207.35),
#  ('put_OfferPrice', 227.9),
#  ('put_OfferQty', 2.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '7,600'),
#  ('call_BidPrice', '1.65'),
#  ('call_OfferPrice', '12.75'),
#  ('call_OfferQty', '6,800'),
#  ('Strike Price', '1780.00'),
#  ('put_BidQty', 2.0),
#  ('put_BidPrice', 225.6),
#  ('put_OfferPrice', 245.9),
#  ('put_OfferQty', 800.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '3,200'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '1,200'),
#  ('call_BidPrice', '1.45'),
#  ('call_OfferPrice', '4.45'),
#  ('call_OfferQty', '1,200'),
#  ('Strike Price', '1800.00'),
#  ('put_BidQty', 800.0),
#  ('put_BidPrice', 242.25),
#  ('put_OfferPrice', 262.65),
#  ('put_OfferQty', 800.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '1,200'),
#  ('call_BidPrice', '0.65'),
#  ('call_OfferPrice', '9.45'),
#  ('call_OfferQty', '1,200'),
#  ('Strike Price', '1820.00'),
#  ('put_BidQty', 800.0),
#  ('put_BidPrice', 261.25),
#  ('put_OfferPrice', 282.1),
#  ('put_OfferQty', 800.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '1,600'),
#  ('call_BidPrice', '0.25'),
#  ('call_OfferPrice', '-'),
#  ('call_OfferQty', '-'),
#  ('Strike Price', '1840.00'),
#  ('put_BidQty', 800.0),
#  ('put_BidPrice', 282.9),
#  ('put_OfferPrice', 301.35),
#  ('put_OfferQty', 800.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None),
#  ('call_Quote', 'Quote'),
#  ('call_OpenInterest', '-'),
#  ('call_Change in Open Interest', '-'),
#  ('call_LTP', '-'),
#  ('call_NetChange', '-'),
#  ('call_Volume', '-'),
#  ('call_BidQty', '2,800'),
#  ('call_BidPrice', '0.25'),
#  ('call_OfferPrice', '-'),
#  ('call_OfferQty', '-'),
#  ('Strike Price', '1860.00'),
#  ('put_BidQty', 800.0),
#  ('put_BidPrice', 302.2),
#  ('put_OfferPrice', 320.7),
#  ('put_OfferQty', 800.0),
#  ('put_Volume', None),
#  ('put_NetChange', None),
#  ('put_LTP', None),
#  ('put_OpenInterest', None),
#  ('put_Change in Open Interest', None),
#  ('put_Quote', None)]

# %% [raw]
# elem = []
# for i, r in enumerate(opt_table):
#     for c in range(len(r)):
#         elem = elem.append(r[c].text_content().strip())
#     row = pd.Series(elem)
#     elem = []

# %%
for k, v in enumerate(opt_table[1:]):
    for m, n in enumerate(v):
        print(symbol, expiry, tbl_header[m],':', n.text_content().strip())
# Out:
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 426.05
# ACC 20181025 OfferPrice : 448.70
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1120.00
# ACC 20181025 BidQty : -
# ACC 20181025 BidPrice : -
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 406.35
# ACC 20181025 OfferPrice : 428.95
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1140.00
# ACC 20181025 BidQty : -
# ACC 20181025 BidPrice : -
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 387.75
# ACC 20181025 OfferPrice : 409.25
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1160.00
# ACC 20181025 BidQty : 400
# ACC 20181025 BidPrice : 0.15
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 367.10
# ACC 20181025 OfferPrice : 389.65
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1180.00
# ACC 20181025 BidQty : 400
# ACC 20181025 BidPrice : 0.15
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 347.60
# ACC 20181025 OfferPrice : 370.10
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1200.00
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 0.15
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 327.95
# ACC 20181025 OfferPrice : 347.90
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1220.00
# ACC 20181025 BidQty : 400
# ACC 20181025 BidPrice : 0.15
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 307.60
# ACC 20181025 OfferPrice : 328.55
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1240.00
# ACC 20181025 BidQty : 1,200
# ACC 20181025 BidPrice : 0.10
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : -
# ACC 20181025 BidPrice : -
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Strike Price : 1260.00
# ACC 20181025 BidQty : 2,400
# ACC 20181025 BidPrice : 0.20
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 269.20
# ACC 20181025 OfferPrice : 292.20
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1280.00
# ACC 20181025 BidQty : 3,600
# ACC 20181025 BidPrice : 0.20
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 249.85
# ACC 20181025 OfferPrice : 274.05
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1300.00
# ACC 20181025 BidQty : 3,600
# ACC 20181025 BidPrice : 0.20
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 230.90
# ACC 20181025 OfferPrice : 255.00
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1320.00
# ACC 20181025 BidQty : 3,600
# ACC 20181025 BidPrice : 0.20
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 215.15
# ACC 20181025 OfferPrice : 232.50
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1340.00
# ACC 20181025 BidQty : 3,600
# ACC 20181025 BidPrice : 0.30
# ACC 20181025 OfferPrice : 9.45
# ACC 20181025 OfferQty : 2,000
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 400
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 195.35
# ACC 20181025 OfferPrice : 213.20
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1360.00
# ACC 20181025 BidQty : 1,200
# ACC 20181025 BidPrice : 1.65
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 1,200
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 178.20
# ACC 20181025 OfferPrice : 194.70
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1380.00
# ACC 20181025 BidQty : 4,800
# ACC 20181025 BidPrice : 1.15
# ACC 20181025 OfferPrice : 12.85
# ACC 20181025 OfferQty : 2,800
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : 400
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 800
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 2,800
# ACC 20181025 BidPrice : 156.40
# ACC 20181025 OfferPrice : 179.60
# ACC 20181025 OfferQty : 2,800
# ACC 20181025 Strike Price : 1400.00
# ACC 20181025 BidQty : 5,200
# ACC 20181025 BidPrice : 5.35
# ACC 20181025 OfferPrice : 14.45
# ACC 20181025 OfferQty : 6,000
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : 6,000
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 143.45
# ACC 20181025 OfferPrice : 162.30
# ACC 20181025 OfferQty : 2,800
# ACC 20181025 Strike Price : 1420.00
# ACC 20181025 BidQty : 8,400
# ACC 20181025 BidPrice : 3.65
# ACC 20181025 OfferPrice : 16.85
# ACC 20181025 OfferQty : 6,000
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : 2,800
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 800
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 2,400
# ACC 20181025 BidPrice : 122.55
# ACC 20181025 OfferPrice : 139.20
# ACC 20181025 OfferQty : 1,600
# ACC 20181025 Strike Price : 1440.00
# ACC 20181025 BidQty : 7,600
# ACC 20181025 BidPrice : 7.70
# ACC 20181025 OfferPrice : 19.90
# ACC 20181025 OfferQty : 6,800
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : 2,000
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 1,200
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 6,000
# ACC 20181025 BidPrice : 107.95
# ACC 20181025 OfferPrice : 125.35
# ACC 20181025 OfferQty : 6,000
# ACC 20181025 Strike Price : 1460.00
# ACC 20181025 BidQty : 5,200
# ACC 20181025 BidPrice : 14.90
# ACC 20181025 OfferPrice : 21.20
# ACC 20181025 OfferQty : 4,000
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : 4,400
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 800
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 5,600
# ACC 20181025 BidPrice : 93.10
# ACC 20181025 OfferPrice : 109.85
# ACC 20181025 OfferQty : 5,600
# ACC 20181025 Strike Price : 1480.00
# ACC 20181025 BidQty : 4,400
# ACC 20181025 BidPrice : 19.60
# ACC 20181025 OfferPrice : 28.25
# ACC 20181025 OfferQty : 6,000
# ACC 20181025 Volume : 2
# ACC 20181025 NetChange : -1.25
# ACC 20181025 LTP : 18.75
# ACC 20181025 OpenInterest : 400
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 1,200
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 4,000
# ACC 20181025 BidPrice : 81.05
# ACC 20181025 OfferPrice : 92.80
# ACC 20181025 OfferQty : 4,000
# ACC 20181025 Strike Price : 1500.00
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 28.65
# ACC 20181025 OfferPrice : 32.95
# ACC 20181025 OfferQty : 5,600
# ACC 20181025 Volume : 15
# ACC 20181025 NetChange : -2.50
# ACC 20181025 LTP : 31.00
# ACC 20181025 OpenInterest : 20,800
# ACC 20181025 Change in Open Interest : 4,000
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 1,600
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 5,200
# ACC 20181025 BidPrice : 70.10
# ACC 20181025 OfferPrice : 77.75
# ACC 20181025 OfferQty : 2,400
# ACC 20181025 Strike Price : 1520.00
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 35.70
# ACC 20181025 OfferPrice : 38.15
# ACC 20181025 OfferQty : 1,600
# ACC 20181025 Volume : 9
# ACC 20181025 NetChange : -5.30
# ACC 20181025 LTP : 36.25
# ACC 20181025 OpenInterest : 12,400
# ACC 20181025 Change in Open Interest : 1,600
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 1,200
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 3,200
# ACC 20181025 BidPrice : 58.45
# ACC 20181025 OfferPrice : 64.20
# ACC 20181025 OfferQty : 400
# ACC 20181025 Strike Price : 1540.00
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 43.00
# ACC 20181025 OfferPrice : 46.70
# ACC 20181025 OfferQty : 2,400
# ACC 20181025 Volume : 14
# ACC 20181025 NetChange : -0.65
# ACC 20181025 LTP : 46.85
# ACC 20181025 OpenInterest : 10,400
# ACC 20181025 Change in Open Interest : 4,000
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 4,000
# ACC 20181025 Change in Open Interest : 800
# ACC 20181025 LTP : 50.25
# ACC 20181025 NetChange : 0.80
# ACC 20181025 Volume : 8
# ACC 20181025 BidQty : 400
# ACC 20181025 BidPrice : 50.35
# ACC 20181025 OfferPrice : 57.15
# ACC 20181025 OfferQty : 5,600
# ACC 20181025 Strike Price : 1560.00
# ACC 20181025 BidQty : 400
# ACC 20181025 BidPrice : 53.35
# ACC 20181025 OfferPrice : 57.70
# ACC 20181025 OfferQty : 5,200
# ACC 20181025 Volume : 7
# ACC 20181025 NetChange : -0.65
# ACC 20181025 LTP : 57.75
# ACC 20181025 OpenInterest : 14,000
# ACC 20181025 Change in Open Interest : 1,600
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 11,200
# ACC 20181025 Change in Open Interest : 2,000
# ACC 20181025 LTP : 46.45
# ACC 20181025 NetChange : 4.40
# ACC 20181025 Volume : 19
# ACC 20181025 BidQty : 400
# ACC 20181025 BidPrice : 42.00
# ACC 20181025 OfferPrice : 42.60
# ACC 20181025 OfferQty : 400
# ACC 20181025 Strike Price : 1580.00
# ACC 20181025 BidQty : 3,200
# ACC 20181025 BidPrice : 60.15
# ACC 20181025 OfferPrice : 68.50
# ACC 20181025 OfferQty : 7,600
# ACC 20181025 Volume : 1
# ACC 20181025 NetChange : -14.35
# ACC 20181025 LTP : 59.95
# ACC 20181025 OpenInterest : 2,400
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 47,200
# ACC 20181025 Change in Open Interest : 4,400
# ACC 20181025 LTP : 35.00
# ACC 20181025 NetChange : 1.50
# ACC 20181025 Volume : 89
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 33.65
# ACC 20181025 OfferPrice : 34.95
# ACC 20181025 OfferQty : 400
# ACC 20181025 Strike Price : 1600.00
# ACC 20181025 BidQty : 8,400
# ACC 20181025 BidPrice : 68.55
# ACC 20181025 OfferPrice : 80.30
# ACC 20181025 OfferQty : 7,600
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : 5,600
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 44,400
# ACC 20181025 Change in Open Interest : 14,400
# ACC 20181025 LTP : 27.45
# ACC 20181025 NetChange : -0.75
# ACC 20181025 Volume : 97
# ACC 20181025 BidQty : 1,200
# ACC 20181025 BidPrice : 26.70
# ACC 20181025 OfferPrice : 28.30
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1620.00
# ACC 20181025 BidQty : 7,600
# ACC 20181025 BidPrice : 80.25
# ACC 20181025 OfferPrice : 97.95
# ACC 20181025 OfferQty : 5,600
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : 2,800
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 13,600
# ACC 20181025 Change in Open Interest : 1,600
# ACC 20181025 LTP : 28.80
# ACC 20181025 NetChange : 8.30
# ACC 20181025 Volume : 12
# ACC 20181025 BidQty : 5,200
# ACC 20181025 BidPrice : 18.10
# ACC 20181025 OfferPrice : 23.00
# ACC 20181025 OfferQty : 400
# ACC 20181025 Strike Price : 1640.00
# ACC 20181025 BidQty : 6,800
# ACC 20181025 BidPrice : 92.90
# ACC 20181025 OfferPrice : 108.00
# ACC 20181025 OfferQty : 6,800
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : 2,400
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 7,600
# ACC 20181025 Change in Open Interest : 400
# ACC 20181025 LTP : 15.45
# ACC 20181025 NetChange : -0.30
# ACC 20181025 Volume : 7
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 15.45
# ACC 20181025 OfferPrice : 23.45
# ACC 20181025 OfferQty : 10,000
# ACC 20181025 Strike Price : 1660.00
# ACC 20181025 BidQty : 6,800
# ACC 20181025 BidPrice : 110.80
# ACC 20181025 OfferPrice : 127.35
# ACC 20181025 OfferQty : 4,800
# ACC 20181025 Volume : 2
# ACC 20181025 NetChange : 2.00
# ACC 20181025 LTP : 117.00
# ACC 20181025 OpenInterest : 1,200
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 96,000
# ACC 20181025 Change in Open Interest : 800
# ACC 20181025 LTP : 14.50
# ACC 20181025 NetChange : 2.75
# ACC 20181025 Volume : 51
# ACC 20181025 BidQty : 400
# ACC 20181025 BidPrice : 12.35
# ACC 20181025 OfferPrice : 15.35
# ACC 20181025 OfferQty : 400
# ACC 20181025 Strike Price : 1680.00
# ACC 20181025 BidQty : 6,800
# ACC 20181025 BidPrice : 126.40
# ACC 20181025 OfferPrice : 140.60
# ACC 20181025 OfferQty : 6,800
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 18,000
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : 11.00
# ACC 20181025 NetChange : 0.55
# ACC 20181025 Volume : 5
# ACC 20181025 BidQty : 2,000
# ACC 20181025 BidPrice : 8.30
# ACC 20181025 OfferPrice : 11.90
# ACC 20181025 OfferQty : 400
# ACC 20181025 Strike Price : 1700.00
# ACC 20181025 BidQty : 4,400
# ACC 20181025 BidPrice : 142.25
# ACC 20181025 OfferPrice : 160.50
# ACC 20181025 OfferQty : 4,400
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : 400
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 2,800
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 1,200
# ACC 20181025 BidPrice : 6.55
# ACC 20181025 OfferPrice : 9.85
# ACC 20181025 OfferQty : 1,200
# ACC 20181025 Strike Price : 1720.00
# ACC 20181025 BidQty : 3,600
# ACC 20181025 BidPrice : 155.85
# ACC 20181025 OfferPrice : 175.50
# ACC 20181025 OfferQty : 1,600
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : 2,000
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 2,000
# ACC 20181025 Change in Open Interest : 1,600
# ACC 20181025 LTP : 6.30
# ACC 20181025 NetChange : -3.20
# ACC 20181025 Volume : 5
# ACC 20181025 BidQty : 1,200
# ACC 20181025 BidPrice : 5.30
# ACC 20181025 OfferPrice : 6.60
# ACC 20181025 OfferQty : 800
# ACC 20181025 Strike Price : 1740.00
# ACC 20181025 BidQty : 3,600
# ACC 20181025 BidPrice : 173.90
# ACC 20181025 OfferPrice : 194.00
# ACC 20181025 OfferQty : 3,600
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 5,200
# ACC 20181025 BidPrice : 1.35
# ACC 20181025 OfferPrice : 14.05
# ACC 20181025 OfferQty : 7,600
# ACC 20181025 Strike Price : 1760.00
# ACC 20181025 BidQty : 2,800
# ACC 20181025 BidPrice : 192.15
# ACC 20181025 OfferPrice : 213.20
# ACC 20181025 OfferQty : 800
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 2,800
# ACC 20181025 BidPrice : 0.95
# ACC 20181025 OfferPrice : 12.85
# ACC 20181025 OfferQty : 6,800
# ACC 20181025 Strike Price : 1780.00
# ACC 20181025 BidQty : 2,800
# ACC 20181025 BidPrice : 213.95
# ACC 20181025 OfferPrice : 232.05
# ACC 20181025 OfferQty : 800
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : 3,200
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 1,200
# ACC 20181025 BidPrice : 0.75
# ACC 20181025 OfferPrice : 4.80
# ACC 20181025 OfferQty : 1,200
# ACC 20181025 Strike Price : 1800.00
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 232.50
# ACC 20181025 OfferPrice : 251.20
# ACC 20181025 OfferQty : 800
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 3,600
# ACC 20181025 BidPrice : 0.40
# ACC 20181025 OfferPrice : 9.85
# ACC 20181025 OfferQty : 1,200
# ACC 20181025 Strike Price : 1820.00
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 251.80
# ACC 20181025 OfferPrice : 270.55
# ACC 20181025 OfferQty : 800
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 1,600
# ACC 20181025 BidPrice : 0.25
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Strike Price : 1840.00
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 268.10
# ACC 20181025 OfferPrice : 290.00
# ACC 20181025 OfferQty : 800
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote
# ACC 20181025 Quote : Quote
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 LTP : -
# ACC 20181025 NetChange : -
# ACC 20181025 Volume : -
# ACC 20181025 BidQty : 1,600
# ACC 20181025 BidPrice : 0.25
# ACC 20181025 OfferPrice : -
# ACC 20181025 OfferQty : -
# ACC 20181025 Strike Price : 1860.00
# ACC 20181025 BidQty : 800
# ACC 20181025 BidPrice : 288.10
# ACC 20181025 OfferPrice : 309.60
# ACC 20181025 OfferQty : 800
# ACC 20181025 Volume : -
# ACC 20181025 NetChange : -
# ACC 20181025 LTP : -
# ACC 20181025 OpenInterest : -
# ACC 20181025 Change in Open Interest : -
# ACC 20181025 Quote : Quote

# %%
from jupyter_core.paths import jupyter_config_dir
jupyter_dir = jupyter_config_dir()
print(jupyter_dir)

# %%
# {Symbol: {Expiry: {Right: {Strike: {Parameter: 'Value'}}}}}
pd.DataFrame({'ACC': {20180901: {'P': {1350: {'OpenInterest': 2000}}}}}).T

# %%
from bs4 import BeautifulSoup as BS

# %%
url = 'https://www.nseindia.com/marketinfo/companyTracker/mtOptionKeys.jsp?companySymbol=ambujacem&indexSymbol=NIFTY&series=EQ&instrument=OPTSTK&date=-'
soup = bs(requests.get(url).text)

# %%
soup.findAll('table')[1].findAll('table')[3]
