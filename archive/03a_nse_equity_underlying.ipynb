# %%
# %%time
# Underlying details extracted from nse
# Program takes 5 mins

# STATUS: Completed

import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs4
import json
import datetime as datetime
import sys

#******         Paths and variables         ****
#_______________________________________________

datapath = r'./zdata/'


#******   Error catch in list comprehension  ****
#________________________________________________

def catch(func, handle=lambda e : e, *args, **kwargs):
    '''List comprehension error catcher'''
    try:
        return func(*args, **kwargs)
    except Exception as e:
        pass
# Out:
# Wall time: 4.44 s

# %%
#******               Symbols list          ****
#________________________________________________
eq_symbols = list(pd.read_pickle(datapath+'df_nse_eq_symbols.pkl').localSymbol.values)

idx_symbols = list(pd.read_pickle(datapath+'df_nse_idx_symbols.pkl').localSymbol.values)

symbols = eq_symbols + idx_symbols

# %%
#******     Underlying data extraction     *****
#_______________________________________________

def get_underlying(symbol):
    
    '''Gets the underlying data
    Arg: (symbol as string)
    Returns: df as dataframe'''

    # URLs
    url_base1 = "https://www.nseindia.com/live_market/dynaContent/live_watch/"
    url = url_base1 + "get_quote/GetQuote.jsp?symbol="+symbol

    page = requests.get(url).text

    # soup out the json dict
    bs_nse = bs4(page, 'html.parser')
    json_nse = json.loads(bs_nse.find(id='responseDiv').text.strip())

    df = pd.DataFrame.from_dict(json_nse['data'][0], orient='index').T
    
    return df

nse_underlyings = [catch(lambda: get_underlying(symbol)) for symbol in symbols]

# indexed by symbols
df_nse_und = pd.concat(nse_underlyings).set_index('symbol')

# clean up the commas, dashes and empty strs
df_nse_und1 = df_nse_und.replace(',|-' , '', regex=True)
df_nse_und1 = df_nse_und1.replace('', np.nan)

# convert date columns to datetime.date format
filtin = ['Date', 'dt']
filtout = ['isExDateFlag']
date_columns_mask = df_nse_und1.columns.str.contains('|'.join(filtin)) | (df_nse_und1.columns.str.contains('|'.join(filtout)))
dt_col_list = df_nse_und1.loc[:, date_columns_mask].columns.tolist()
dt_col_list = [item for item in dt_col_list if item not in filtout]  #filterout

df_nse_und1.loc[:, dt_col_list] = df_nse_und1.loc [:, dt_col_list].apply( \
                                  pd.to_datetime, errors= 'coerce').applymap(pd.Timestamp.date)

# store data for next program
df_nse_und1.to_pickle(datapath+r'df_underlying.pkl')

# %%
df_nse_und1.reset_index().symbol.unique()
# Out:
# array(['ACC', 'ADANIENT', 'ADANIPORTS', 'ADANIPOWER', 'AJANTPHARM',
#        'ALBK', 'AMARAJABAT', 'AMBUJACEM', 'APOLLOHOSP', 'APOLLOTYRE',
#        'ARVIND', 'ASHOKLEY', 'ASIANPAINT', 'AUROPHARMA', 'AXISBANK',
#        'BAJAJ-AUTO', 'BAJAJFINSV', 'BAJFINANCE', 'BALKRISIND',
#        'BANKBARODA', 'BANKINDIA', 'BATAINDIA', 'BEL', 'BEML',
#        'BERGEPAINT', 'BHARATFIN', 'BHARATFORG', 'BHARTIARTL', 'BHEL',
#        'BIOCON', 'BOSCHLTD', 'BPCL', 'BRITANNIA', 'CADILAHC', 'CANBK',
#        'CANFINHOME', 'CAPF', 'CASTROLIND', 'CEATLTD', 'CENTURYTEX',
#        'CESC', 'CGPOWER', 'CHENNPETRO', 'CHOLAFIN', 'CIPLA', 'COALINDIA',
#        'COLPAL', 'CONCOR', 'CUMMINSIND', 'DABUR', 'DALMIABHA', 'DCBBANK',
#        'DHFL', 'DISHTV', 'DIVISLAB', 'DLF', 'DRREDDY', 'EICHERMOT',
#        'ENGINERSIN', 'EQUITAS', 'ESCORTS', 'EXIDEIND', 'FEDERALBNK',
#        'GAIL', 'GLENMARK', 'GMRINFRA', 'GODFRYPHLP', 'GODREJCP',
#        'GODREJIND', 'GRANULES', 'GRASIM', 'GSFC', 'HAVELLS', 'HCC',
#        'HCLTECH', 'HDFC', 'HDFCBANK', 'HEROMOTOCO', 'HEXAWARE',
#        'HINDALCO', 'HINDPETRO', 'HINDUNILVR', 'HINDZINC', 'IBULHSGFIN',
#        'ICICIBANK', 'ICICIPRULI', 'IDBI', 'IDEA', 'IDFC', 'IDFCBANK',
#        'IFCI', 'IGL', 'INDIACEM', 'INDIANB', 'INDIGO', 'INDUSINDBK',
#        'INFIBEAM', 'INFRATEL', 'INFY', 'IOC', 'IRB', 'ITC', 'JETAIRWAYS',
#        'JINDALSTEL', 'JISLJALEQS', 'JPASSOCIAT', 'JSWSTEEL', 'JUBLFOOD',
#        'JUSTDIAL', 'KAJARIACER', 'KOTAKBANK', 'KPIT', 'KSCL', 'KTKBANK',
#        'LICHSGFIN', 'LT', 'LUPIN', 'MANAPPURAM', 'MARICO', 'MARUTI',
#        'MCDOWELL-N', 'MCX', 'MFSL', 'MGL', 'MINDTREE', 'MOTHERSUMI',
#        'MRF', 'MRPL', 'MUTHOOTFIN', 'NATIONALUM', 'NBCC', 'NCC',
#        'NESTLEIND', 'NHPC', 'NIITTECH', 'NMDC', 'NTPC', 'OFSS', 'OIL',
#        'ONGC', 'ORIENTBANK', 'PAGEIND', 'PCJEWELLER', 'PEL', 'PETRONET',
#        'PFC', 'PIDILITIND', 'PNB', 'POWERGRID', 'PTC', 'PVR', 'RAMCOCEM',
#        'RAYMOND', 'RBLBANK', 'RCOM', 'RECLTD', 'RELCAPITAL', 'RELIANCE',
#        'RELINFRA', 'REPCOHOME', 'RPOWER', 'SAIL', 'SBIN', 'SHREECEM',
#        'SIEMENS', 'SOUTHBANK', 'SREINFRA', 'SRF', 'SRTRANSFIN', 'STAR',
#        'SUNPHARMA', 'SUNTV', 'SUZLON', 'SYNDIBANK', 'TATACHEM',
#        'TATACOMM', 'TATAELXSI', 'TATAGLOBAL', 'TATAMOTORS', 'TATAMTRDVR',
#        'TATAPOWER', 'TATASTEEL', 'TCS', 'TECHM', 'TITAN', 'TORNTPHARM',
#        'TORNTPOWER', 'TV18BRDCST', 'TVSMOTOR', 'UBL', 'UJJIVAN',
#        'ULTRACEMCO', 'UNIONBANK', 'UPL', 'VEDL', 'VGUARD', 'VOLTAS',
#        'WIPRO', 'WOCKPHARMA', 'YESBANK', 'ZEEL'], dtype=object)

# UJJIVAN            NaN             Ujjivan Financial Services Limited
# ULTRACEMCO         NaN                       UltraTech Cement Limited
# UNIONBANK          NaN                            Union Bank of India
# UPL                NaN                                    UPL Limited
# VEDL               NaN                                Vedanta Limited
# VGUARD             NaN                      VGuard Industries Limited
# VOLTAS             NaN                                 Voltas Limited
# WIPRO              NaN                                  Wipro Limited
# WOCKPHARMA         NaN                              Wockhardt Limited
# YESBANK            NaN                               Yes Bank Limited
# ZEEL               NaN          Zee Entertainment Enterprises Limited
#
#            marketType      exDate bcStartDate css_status_desc    ...     \
# symbol                                                           ...
# ACC                 N  2018-05-17  2018-05-21          Listed    ...
# ADANIENT            N  2018-09-06  0001-01-01          Listed    ...
# ADANIPORTS          N  2018-07-26  2018-07-30          Listed    ...
# ADANIPOWER          N  2018-07-26  2018-07-30          Listed    ...
# AJANTPHARM          N  2018-11-09  0001-01-01          Listed    ...
# ALBK                N  2018-06-19  2018-06-21          Listed    ...
# AMARAJABAT          N  2018-11-20  0001-01-01          Listed    ...
# AMBUJACEM           N  2018-04-05  2018-04-09          Listed    ...
# APOLLOHOSP          N  2018-09-12  2018-09-15          Listed    ...
# APOLLOTYRE          N  2018-07-18  2018-07-20          Listed    ...
# ARVIND              N  2018-11-28  0001-01-01          Listed    ...
# ASHOKLEY            N  2018-07-09  2018-07-11          Listed    ...
# ASIANPAINT          N  2018-10-29  0001-01-01          Listed    ...
# AUROPHARMA          N  2018-11-20  0001-01-01          Listed    ...
# AXISBANK            N  2018-05-31  2018-06-02          Listed    ...
# BAJAJ-AUTO          N  2018-07-05  2018-07-07          Listed    ...
# BAJAJFINSV          N  2018-07-05  2018-07-07          Listed    ...
# BAJFINANCE          N  2018-07-05  2018-07-07          Listed    ...
# BALKRISIND          N  2018-11-14  0001-01-01          Listed    ...
# BANKBARODA          N  2018-07-05  2018-07-07          Listed    ...
# BANKINDIA           N  2018-07-05  2018-07-09          Listed    ...
# BATAINDIA           N  2018-07-09  2018-07-11          Listed    ...
# BEL                 N  2018-08-20  2018-08-22          Listed    ...
# BEML                N  2018-09-19  2018-09-22          Listed    ...
# BERGEPAINT          N  2018-07-26  2018-07-28          Listed    ...
# BHARATFIN           N  2018-07-18  2018-07-20          Listed    ...
# BHARATFORG          N  2018-11-15  0001-01-01          Listed    ...
# BHARTIARTL          N  2018-11-05  0001-01-01          Listed    ...
# BHEL                N  2018-11-05  0001-01-01          Listed    ...
# BIOCON              N  2018-07-19  0001-01-01          Listed    ...
# ...               ...         ...         ...             ...    ...
# SUNTV               N  2018-11-14  0001-01-01          Listed    ...
# SUZLON              N  2018-07-19  2018-07-21          Listed    ...
# SYNDIBANK           N  2018-06-20  2018-06-22          Listed    ...
# TATACHEM            N  2018-07-16  2018-07-18          Listed    ...
# TATACOMM            N  2018-08-01  2018-08-03          Listed    ...
# TATAELXSI           N  2018-07-16  2018-07-18          Listed    ...
# TATAGLOBAL          N  2018-06-20  2018-06-22          Listed    ...
# TATAMOTORS          N  2016-07-18  2016-07-20          Listed    ...
# TATAMTRDVR          N  2016-07-18  2016-07-20          Listed    ...
# TATAPOWER           N  2018-07-12  2018-07-14          Listed    ...
# TATASTEEL           N  2018-07-05  2018-07-07          Listed    ...
# TCS                 N  2018-10-23  0001-01-01          Listed    ...
# TECHM               N  2018-07-26  2018-07-28          Listed    ...
# TITAN               N  2018-07-23  2018-07-25          Listed    ...
# TORNTPHARM          N  2018-06-18  2018-06-20          Listed    ...
# TORNTPOWER          N  2018-06-08  2018-06-12          Listed    ...
# TV18BRDCST          N  2018-08-10  2018-08-14          Listed    ...
# TVSMOTOR            N  2018-10-30  0001-01-01          Listed    ...
# UBL                 N  2018-09-07  2018-09-11          Listed    ...
# UJJIVAN             N  2018-06-19  2018-06-21          Listed    ...
# ULTRACEMCO          N  2018-07-10  2018-07-12          Listed    ...
# UNIONBANK           N  2018-06-19  2018-06-21          Listed    ...
# UPL                 N  2018-08-09  2018-08-11          Listed    ...
# VEDL                N  2018-11-06  0001-01-01          Listed    ...
# VGUARD              N  2018-07-23  2018-07-25          Listed    ...
# VOLTAS              N  2018-08-03  2018-08-07          Listed    ...
# WIPRO               N  2018-07-13  2018-07-17          Listed    ...
# WOCKPHARMA          N  2018-07-25  2018-07-27          Listed    ...
# YESBANK             N  2018-06-04  2018-06-06          Listed    ...
# ZEEL                N  2018-07-09  0001-01-01          Listed    ...
#
#            buyQuantity3 buyQuantity2 buyQuantity1 series  faceValue  \
# symbol
# ACC                 NaN          NaN          NaN     EQ      10.00
# ADANIENT            NaN          NaN          NaN     EQ       1.00
# ADANIPORTS          NaN          NaN           35     EQ       2.00
# ADANIPOWER          NaN          NaN       153443     EQ      10.00
# AJANTPHARM          NaN          NaN         2485     EQ       2.00
# ALBK                NaN          NaN        55739     EQ      10.00
# AMARAJABAT          NaN          NaN          298     EQ       1.00
# AMBUJACEM           NaN          NaN          NaN     EQ       2.00
# APOLLOHOSP          NaN          NaN          NaN     EQ       5.00
# APOLLOTYRE          NaN          NaN          512     EQ       1.00
# ARVIND              NaN          NaN          NaN     EQ      10.00
# ASHOKLEY            NaN          NaN        35994     EQ       1.00
# ASIANPAINT          NaN          NaN         1987     EQ       1.00
# AUROPHARMA          NaN          NaN          NaN     EQ       1.00
# AXISBANK            NaN          NaN          NaN     EQ       2.00
# BAJAJ-AUTO          NaN          NaN            7     EQ      10.00
# BAJAJFINSV          NaN          NaN          236     EQ       5.00
# BAJFINANCE          NaN          NaN          795     EQ       2.00
# BALKRISIND          NaN          NaN          NaN     EQ       2.00
# BANKBARODA          NaN          NaN          NaN     EQ       2.00
# BANKINDIA           NaN          NaN         6881     EQ      10.00
# BATAINDIA           NaN          NaN          NaN     EQ       5.00
# BEL                 NaN          NaN          NaN     EQ       1.00
# BEML                NaN          NaN           51     EQ      10.00
# BERGEPAINT          NaN          NaN         1732     EQ       1.00
# BHARATFIN           NaN          NaN          NaN     EQ      10.00
# BHARATFORG          NaN          NaN          NaN     EQ       2.00
# BHARTIARTL          NaN          NaN         4537     EQ       5.00
# BHEL                NaN          NaN         1234     EQ       2.00
# BIOCON              NaN          NaN          NaN     EQ       5.00
# ...                 ...          ...          ...    ...        ...
# SUNTV               NaN          NaN           10     EQ       5.00
# SUZLON              NaN          NaN       619616     EQ       2.00
# SYNDIBANK           NaN          NaN          NaN     EQ      10.00
# TATACHEM            NaN          NaN          263     EQ      10.00
# TATACOMM            NaN          NaN          539     EQ      10.00
# TATAELXSI           NaN          NaN          229     EQ      10.00
# TATAGLOBAL          NaN          NaN         1278     EQ       1.00
# TATAMOTORS          NaN          NaN         9764     EQ       2.00
# TATAMTRDVR          NaN          NaN          524     EQ       2.00
# TATAPOWER           NaN          NaN          NaN     EQ       1.00
# TATASTEEL           NaN          NaN          248     EQ      10.00
# TCS                 NaN          NaN          NaN     EQ       1.00
# TECHM               NaN          NaN          NaN     EQ       5.00
# TITAN               NaN          NaN          NaN     EQ       1.00
# TORNTPHARM          NaN          NaN          326     EQ       5.00
# TORNTPOWER          NaN          NaN          NaN     EQ      10.00
# TV18BRDCST          NaN          NaN         8636     EQ       2.00
# TVSMOTOR            NaN          NaN           10     EQ       1.00
# UBL                 NaN          NaN          922     EQ       1.00
# UJJIVAN             NaN          NaN          819     EQ      10.00
# ULTRACEMCO          NaN          NaN          NaN     EQ      10.00
# UNIONBANK           NaN          NaN         1430     EQ      10.00
# UPL                 NaN          NaN          NaN     EQ       2.00
# VEDL                NaN          NaN          NaN     EQ       1.00
# VGUARD              NaN          NaN        10072     EQ       1.00
# VOLTAS              NaN          NaN          NaN     EQ       1.00
# WIPRO               NaN          NaN          NaN     EQ       2.00
# WOCKPHARMA          NaN          NaN          590     EQ       5.00
# YESBANK             NaN          NaN        74515     EQ       2.00
# ZEEL                NaN          NaN          NaN     EQ       1.00
#
#             buyQuantity5  closePrice     open      isinCode lastPrice
# symbol
# ACC                  NaN     1501.65  1502.60  INE012A01025   1489.90
# ADANIENT             NaN      162.10   162.40  INE423A01024    162.00
# ADANIPORTS           NaN      350.55   348.20  INE742F01042    351.00
# ADANIPOWER           NaN       47.40    47.55  INE814H01011     48.00
# AJANTPHARM           NaN     1136.55  1120.00  INE031B01049   1143.75
# ALBK                 NaN       43.55    43.40  INE428A01015     44.00
# AMARAJABAT           NaN      732.55   737.90  INE885A01032    732.15
# AMBUJACEM            NaN      220.40   218.00  INE079A01024    221.00
# APOLLOHOSP           NaN     1225.05  1235.00  INE437A01024   1225.50
# APOLLOTYRE           NaN      229.15   226.60  INE438A01022    229.50
# ARVIND               NaN      317.75   320.90  INE034A01011    317.35
# ASHOKLEY             NaN      108.80   105.95  INE208A01029    108.95
# ASIANPAINT           NaN     1312.15  1329.00  INE021A01026   1320.00
# AUROPHARMA           NaN      794.00   786.15  INE406A01037    791.10
# AXISBANK             NaN      616.30   619.80  INE238A01034    617.60
# BAJAJ-AUTO           NaN     2679.65  2704.00  INE917I01010   2680.25
# BAJAJFINSV           NaN     5725.95  5720.00  INE918I01018   5739.00
# BAJFINANCE           NaN     2360.95  2420.00  INE296A01024   2367.00
# BALKRISIND           NaN      965.35   956.55  INE787D01026    965.35
# BANKBARODA           NaN      115.35   116.40  INE028A01039    115.20
# BANKINDIA            NaN       87.45    88.70  INE084A01016     87.80
# BATAINDIA            NaN      994.85  1010.00  INE176A01028    994.50
# BEL                  NaN       93.90    93.00  INE263A01024     93.65
# BEML                 NaN      730.30   700.00  INE258A01016    730.40
# BERGEPAINT           NaN      315.50   317.00  INE463A01038    316.90
# BHARATFIN            NaN      953.60   929.70  INE180K01011    956.00
# BHARATFORG           NaN      594.85   593.55  INE465A01025    593.30
# BHARTIARTL           NaN      336.85   329.40  INE397D01024    337.00
# BHEL                 NaN       68.00    66.80  INE257A01026     68.05
# BIOCON               NaN      630.05   625.30  INE376G01013    630.70
# ...                  ...         ...      ...           ...       ...
# SUNTV                NaN      617.05   613.20  INE424H01027    617.85
# SUZLON               NaN        5.40     5.70  INE040H01021      5.50
# SYNDIBANK            NaN       36.00    37.00  INE667A01018     36.05
# TATACHEM             NaN      700.00   698.80  INE092A01019    700.10
# TATACOMM             NaN      538.00   544.60  INE151A01013    537.45
# TATAELXSI            NaN      982.70   962.55  INE670A01012    985.00
# TATAGLOBAL           NaN      224.15   222.00  INE192A01025    224.10
# TATAMOTORS           NaN      184.60   180.60  INE155A01022    184.80
# TATAMTRDVR           NaN      101.10    99.85  IN9155A01020    101.35
# TATAPOWER            NaN       77.35    76.90  INE245A01021     77.20
# TATASTEEL            NaN      582.40   577.45  INE081A01012    582.30
# TCS                  NaN     1902.45  1899.00  INE467B01029   1902.00
# TECHM                NaN      732.55   730.00  INE669C01036    730.65
# TITAN                NaN      920.55   922.00  INE280A01028    921.00
# TORNTPHARM           NaN     1671.40  1665.00  INE685A01028   1675.00
# TORNTPOWER           NaN      260.50   264.25  INE813H01021    260.10
# TV18BRDCST           NaN       37.10    37.20  INE886H01027     37.10
# TVSMOTOR             NaN      554.95   550.60  INE494B01023    555.00
# UBL                  NaN     1317.65  1314.90  INE686F01025   1319.95
# UJJIVAN              NaN      230.85   231.30  INE334L01012    231.20
# ULTRACEMCO           NaN     4031.95  3970.40  INE481G01011   4024.00
# UNIONBANK            NaN       81.75    84.00  INE692A01016     82.10
# UPL                  NaN      775.20   773.00  INE628A01036    775.50
# VEDL                 NaN      211.35   207.80  INE205A01025    211.50
# VGUARD               NaN      195.60   196.40  INE951I01027    197.40
# VOLTAS               NaN      561.65   552.55  INE226A01021    561.00
# WIPRO                NaN      332.85   325.50  INE075A01022    330.95
# WOCKPHARMA           NaN      526.70   528.00  INE049B01025    525.15
# YESBANK              NaN      204.80   198.10  INE528G01027    205.95
# ZEEL                 NaN      446.80   449.95  INE256A01028    447.00
#
# [201 rows x 67 columns]
